# %% [markdown]
# # **Import Library**

# %%
# %pip install google-play-scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import reviews_all, Sort # Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.

# %% [markdown]
# # Scapping Dataset
#
# Pada proyek ini, kita akan melakukan analisis sentimen terhadap ulasan dan pendapat pengguna terkait aplikasi "8 Ball Pool" di Play Store. Analisis sentimen akan membantu kita untuk memahami bagaimana pengguna merasakan dan mengungkapkan pandangan mereka terhadap aplikasi ini.
#
# Dengan menggunakan berbagai teknik pemrosesan teks dan algoritma machine learning, kita akan mencoba mengidentifikasi apakah ulasan pengguna terhadap aplikasi "8 Ball Pool" cenderung positif, negatif, atau netral. Hasil analisis sentimen ini dapat memberikan wawasan berharga kepada pengembang aplikasi untuk meningkatkan pengalaman pengguna. Mari kita mulai menjelajahi ulasan pengguna dan menganalisis sentimen di sekitar aplikasi "8 Ball Pool" dengan lebih mendalam.

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.miniclip.eightballpool' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.miniclip.eightballpool', # ID aplikasi
    lang='en',                    # Bahasa ulasan (default: 'en')
    country='us',                 # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT,      # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=100000                  # Jumlah maksimum ulasan yang ingin diambil
)

# %% [markdown]
# # Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
# Out:
# (103500, 11)

# %%
app_reviews_df.to_csv('ulasan_aplikasi_8ballpool.csv', index=False)
app_reviews_df.head()
# Out:
#                                reviewId       userName  \
# 0  2b9ca97c-4c86-43cc-8d93-89f76c7db22e  A Google user
# 1  eaaad21c-8b40-4e84-9535-c3cf75ff6cff  A Google user
# 2  e341328b-9964-417d-8290-eb7d506a41f9  A Google user
# 3  0ed0cade-7269-4889-a87e-20661047fbdf  A Google user
# 4  3a70a51a-eb78-431d-b922-5cea1363313d  A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Game is very fun and helps you learn about pla...      2             21
# 1  Would rate it higher, but the physics in this ...      2            109
# 2  This game is straight up fixed. Insane English...      1             12
# ...
